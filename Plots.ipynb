# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Plotting code: Alter the code below with the accuracy rates printed out during training and validation

# %%
fig, ax =plt.subplots(1,1)
data = [['Epoch 1','0.00%'],
      ['Epoch 2','1.60%'],
      ['Epoch 3','19.2%'],
      ['Post-Training Validation','42.6%']]
col_labels = ['Time of validation','Percent of correct grasps']
ax.axis('tight')
ax.axis('off')
ax.table(cellText=data,loc="center", colLabels = col_labels,colColours =["orange"] * 3)

plt.show()
plt.savefig('TrainingScenario4_Table.png')
